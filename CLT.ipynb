# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def mean_and_std(sample1, sample2):
    print("Sample 1 Mean: ", sample1.mean())
    print("Sample 2 Mean: ", sample2.mean())
    print("Sample 1 STD: ", sample1.std())
    print("Sample 2 STD: ", sample2.std())

    diff=sample2.mean( ) -sample1.mean()
    print("Sample Mean Difference: ", diff)

# %%
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 

# Let’s make histograms for the two groups. 

plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()
mean_and_std(sample1, sample2)
# Out:
# Sample 1 Mean:  2.26
# Sample 2 Mean:  5.22
# Sample 1 STD:  1.39010790948
# Sample 2 STD:  1.63450298256
# Sample Mean Difference:  2.96

# %%
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()
mean_and_std(sample1, sample2)
# Out:
# Sample 1 Mean:  1.99
# Sample 2 Mean:  4.944
# Sample 1 STD:  1.27824097885
# Sample 2 STD:  1.58077955452
# Sample Mean Difference:  2.954

# %%
sample1 = np.random.choice(pop1, 20, replace=True)
sample2 = np.random.choice(pop2, 20, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()
mean_and_std(sample1, sample2)
# Out:
# Sample 1 Mean:  2.15
# Sample 2 Mean:  4.6
# Sample 1 STD:  1.23592070943
# Sample 2 STD:  1.39283882772
# Sample Mean Difference:  2.45

# %%
pop1 = np.random.binomial(10, 0.3, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 

# Let’s make histograms for the two groups. 

plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()
mean_and_std(sample1, sample2)
# Out:
# Sample 1 Mean:  3.2
# Sample 2 Mean:  5.02
# Sample 1 STD:  1.37113092008
# Sample 2 STD:  1.57467456955
# Sample Mean Difference:  1.82

# %%
from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# Ttest_indResult(statistic=8.6729264483904558, pvalue=1.6662718081187527e-15)

# %%
pop1 = np.random.binomial(10, 0.4, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 

# Let’s make histograms for the two groups. 

plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()
mean_and_std(sample1, sample2)
# Out:
# Sample 1 Mean:  4.05
# Sample 2 Mean:  5.35
# Sample 1 STD:  1.68151717208
# Sample 2 STD:  1.68745370307
# Sample Mean Difference:  1.3

# %%
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# Ttest_indResult(statistic=5.429727279154192, pvalue=1.6418527783905322e-07)
